# %% [markdown]
# # Part II - (UsedCarsSA)
# ## by (Abdulmajeed Duraibi)

# %% [markdown]
# ## Investigation Overview
#
# In this project I tried to investigate all feature in the UsedCarsSA dataset. I used the Question-Visualization-Observations framework in the investigation process. Here are three visualizations I'll present
#
# <ol>
#   <li>What is most popular gear type for selling cars? (univariate)</li>
#   <li>Does the price increase by car's year? (Bivariate)</li>
#   <li>Is there relation between Price and Year and Gear Type? (Multivariate)</li>
# </ol>

# %% [markdown]
# ## Dataset Overview
#
# [Saudi Arabia Used Cars](https://www.kaggle.com/datasets/turkibintalib/saudi-arabia-used-cars-dataset?d) dataset was selected based on Udacity standards.The dataset related to used cars collected from [Syarah](https://syarah.com/) that enables users to sell their cars. The following is a brief description of all the features in the dataset
# - Make: Company that makes the car, such: Hyundai, Toyota, Mercedes
# - Type: Name of the car, such: Elantra, Camry, CLA
# - Year: Model of car, such: 2020, 2021, 2022
# - Origin: Options of the car: such saudi options, Gulf arabic
# - Color: Color of the car, such: Black, White, Blue
# - Options: if Options = full, that means the car have full options
# - Engine_Size: such 5.7
# - Fuel_Type: such: Gas, Diesel
# - Gear_Type: such: Manuel, Automatic
# - Mileage: such 103000 in KM
# - Region: such Riyadh, Jeddah
# - Price: such 114000 SAR
# - Negotiable: is price negotiable or not
# - Which fuel type is most popular across all regions?

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

color = sb.color_palette()[0]

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df = pd.read_csv('UsedCarsSA.csv')

# %% [markdown]
# ## Proportion of Gear Type
# **About 87% of cars used Automatic gear** <br>
# **About 13% of cars used Manual gear**

# %%
Manual = df[df['Gear_Type'] == 'Manual'].count()
Automatic = df[df['Gear_Type'] == 'Automatic'].count()
Gear_Type = [Automatic[1], Manual[1]]
sorted_counts = df['Gear_Type'].value_counts()
plt.pie(Gear_Type, labels = sorted_counts.index , autopct="%1.2f%%", explode = [0,0.04], startangle = 90, counterclock = False)
plt.title('Proportion of Gear Type')
plt.show()

# %% [markdown]
# ## Car's Year VS Car's Price
#
# **In 1980 and 1990 car's year the average price is high** <br>
# **Since 2000, the average price of cars has increased**

# %%
sb.lineplot(data=df, x="Year", y="Price")
plt.title("Average Car's price by Car's Year");

# %% [markdown]
# ## Average Car's price by Car's Year Group by Gear Type
# **The `Automatic` cars is `higher-priced` than `Manual` when car's year increase**

# %%
g = sb.FacetGrid(data = df, hue = 'Gear_Type', height = 7)
g.map(plt.scatter, 'Year', 'Price', alpha = 0.3, s=4)
g.add_legend();
plt.title("Average Car's price by Car's Year Group by Gear Type");
